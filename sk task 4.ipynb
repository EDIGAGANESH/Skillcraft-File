# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Dataset Overview
data = pd.read_csv('US_Accidents_March23.csv')

# %%
data.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
data.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
data.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
data.shape
# Out:
# (7728394, 46)

# %%
data.dtypes
# Out:
# ID                        object
# Source                    object
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Street                    object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# ...

# %%
print("\nColumn Names:\n", data.columns.tolist())

# Verify key columns
key_columns = ['Start_Time', 'Weather_Condition', 'Start_Lat', 'Start_Lng', 'Severity']
missing_columns = [col for col in key_columns if col not in data.columns]
if missing_columns:
    print(f"\nError: Columns {missing_columns} not found. Please check dataset columns and update code.")
    exit()
print("\nMissing Values in Key Columns:\n", data[key_columns].isnull().sum())
print("\nUnique Weather Conditions (Top 10):\n", data['Weather_Condition'].value_counts().head(10))
# Out:
# Column Names:
#  ['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight']
#
# Missing Values in Key Columns:
#  Start_Time                0
# Weather_Condition    173459
# Start_Lat                 0
# Start_Lng                 0
# Severity                  0
# dtype: int64
#
# Unique Weather Conditions (Top 10):
#  Weather_Condition
# Fair                2560802
# Mostly Cloudy       1016195
# ...

# %%
#Preprocessing
data['Start_Time'] = pd.to_datetime(data['Start_Time'], errors='coerce')
data['Hour'] = data['Start_Time'].dt.hour
data = data.dropna(subset=key_columns)
relevant_columns = ['Start_Time', 'Hour', 'Weather_Condition', 'Start_Lat', 'Start_Lng', 'Severity', 'Traffic_Signal', 'Junction', 'Crossing']
available_columns = [col for col in relevant_columns if col in data.columns]
data = data[available_columns]
print("\nPreprocessed Dataset Shape:", data.shape)
print("\nPreprocessed Columns:\n", data.columns.tolist())
data.to_csv('preprocessed_accidents.csv', index=False)
print("\nPreprocessed data saved to 'preprocessed_accidents.csv'.")
# Out:
# Preprocessed Dataset Shape: (6829766, 9)
#
# Preprocessed Columns:
#  ['Start_Time', 'Hour', 'Weather_Condition', 'Start_Lat', 'Start_Lng', 'Severity', 'Traffic_Signal', 'Junction', 'Crossing']
#
# Preprocessed data saved to 'preprocessed_accidents.csv'.

# %%
#Analysis
# Time of Day
hourly_accidents = data['Hour'].value_counts().sort_index()
print("\nHourly Accident Counts:\n", hourly_accidents)
# Out:
# Hourly Accident Counts:
#  Hour
# 0.0      95463
# 1.0      83215
# 2.0      79943
# 3.0      72119
# 4.0     145244
# 5.0     204287
# 6.0     366483
# 7.0     535533
# 8.0     530516
# 9.0     326711
# 10.0    306584
# 11.0    315284
# 12.0    310080
# 13.0    344618
# 14.0    386145
# 15.0    453724
# 16.0    510056
# 17.0    506520
# 18.0    382530
# 19.0    261134
# 20.0    196887
# 21.0    165029
# 22.0    144466
# 23.0    107195
# Name: count, dtype: int64

# %%
# Weather
weather_accidents = data['Weather_Condition'].value_counts().head(10)
print("\nTop 10 Weather Conditions:\n", weather_accidents)
# Out:
# Top 10 Weather Conditions:
#  Weather_Condition
# Fair                2206054
# Mostly Cloudy        923515
# Clear                808231
# Cloudy               715030
# Partly Cloudy        635456
# Overcast             382802
# Light Rain           322207
# Scattered Clouds     204782
# Light Snow           112300
# Fog                   88488
# Name: count, dtype: int64

# %%
# Road Conditions (use Traffic_Signal if available, else Weather_Condition)
road_condition_column = 'Weather_Condition'
if 'Traffic_Signal' in data.columns:
    road_condition_column = 'Traffic_Signal'
    road_condition_accidents = data['Traffic_Signal'].value_counts()
else:
    road_condition_accidents = data['Weather_Condition'].value_counts().head(10)

# %%
# Severity by Weather
severity_weather = data.groupby('Weather_Condition')['Severity'].mean().sort_values(ascending=False).head(10)
print("\nTop 10 Weather Conditions by Severity:\n", severity_weather)
# Out:
# Top 10 Weather Conditions by Severity:
#  Weather_Condition
# Light Blowing Snow              3.666667
# Patches of Fog / Windy          3.142857
# Light Fog                       3.000000
# Heavy Freezing Rain / Windy     3.000000
# Partial Fog / Windy             3.000000
# Heavy Thunderstorms and Snow    2.800000
# Light Thunderstorms and Snow    2.772727
# Heavy Ice Pellets               2.750000
# Heavy Blowing Snow              2.750000
# Heavy Snow with Thunder         2.714286
# Name: Severity, dtype: float64

# %%
#Visualization
# Accidents by Hour
plt.figure(figsize=(10, 6))
sns.barplot(x=hourly_accidents.index, y=hourly_accidents.values, color='skyblue')
plt.title('Accidents by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Accidents')
plt.grid(axis='y')
plt.show()

# %%
# Accidents by Weather Condition
plt.figure(figsize=(12, 6))
sns.barplot(x=weather_accidents.values, y=weather_accidents.index, color='lightgreen')
plt.title('Top 10 Weather Conditions for Accidents')
plt.xlabel('Number of Accidents')
plt.ylabel('Weather Condition')
plt.grid(axis='x')
plt.show()

# %%
# Accidents by Road Condition
plt.figure(figsize=(12, 6))
sns.barplot(x=road_condition_accidents.values, y=road_condition_accidents.index.astype(str), color='lightblue')
plt.title(f'Accidents by Road Condition ({road_condition_column} as Proxy)')
plt.xlabel('Number of Accidents')
plt.ylabel('Condition')
plt.grid(axis='x')
plt.show()

# %%
# Accident Hotspots (Scatter Plot)
plt.figure(figsize=(12, 8))
sample_data = data.sample(10000, random_state=42)
plt.scatter(sample_data['Start_Lng'], sample_data['Start_Lat'], s=2, alpha=0.2, c='red')
plt.title('Accident Hotspots (Start_Lat vs Start_Lng)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
# Severity by Weather
plt.figure(figsize=(12, 6))
sns.barplot(x=severity_weather.values, y=severity_weather.index, color='salmon')
plt.title('Average Accident Severity by Weather Condition')
plt.xlabel('Average Severity (1-4)')
plt.ylabel('Weather Condition')
plt.grid(axis='x')
plt.show()
